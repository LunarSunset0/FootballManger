# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # Data visualization
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
import os

# %%
df = pd.read_csv("dataset.csv")
df = df.drop(["NationID","Born","IntCaps","IntGoals","U21Caps","U21Goals","Height","Weight"], axis=1)
df.head()
# Out:
#        UID            Name  Age  AerialAbility  CommandOfArea  Communication  \
# 0  1000055  Wilfred Bamnjo   36              1              1              2
# 1  1000331        Wang Wei   34             12              3              5
# 2  1000334        Liu Yang   34              1              2              4
# 3  1000337         Song Qi   31              1              3              1
# 4  1000340        Chen Lei   33              3              3              2
#
#    Eccentricity  Handling  Kicking  OneOnOnes      ...        \
# 0             2         3        3          1      ...
# 1             1        12        6          2      ...
# 2             2         1        1          1      ...
# 3             3         2        2          1      ...
# 4             3         1        1          3      ...
#
#    AttackingMidRight  DefenderCentral  DefenderLeft  DefenderRight  \
# 0                  1                1             1              1
# ...

# %%
#Best Wonderkids of 2017 Football Manager
GK = "Gianluigi Donnarumma"
RB = "Joshua Kimmich"
CB = "Jonathan Tah"
CB = "Alessio Romagnoli"
LB = "Luke Shaw"
CDM = "Renato Sanches"
#CDM = "Leon Goretzka"
CAM = "Marco Asensio"
RW = "Ousmane Dembele"
LW = "Leroy Sane"
CF = "Anthony Martial"

# %%
#What stats matter the most to the GK postion
GKStats = ["Name","AerialAbility","CommandOfArea","Communication","Eccentricity","Handling","Kicking","OneOnOnes"
           ,"Reflexes","RushingOut","TendencyToPunch","Throwing"]

BestGK = "Manuel Neuer"
YouthGK = GK

BestGKstats = df.loc[df['Name'] == BestGK]
BestGKstats = BestGKstats[GKStats]
YouthGKstats = df.loc[df['Name'] == YouthGK]
YouthGKstats = YouthGKstats[GKStats]

# %%
BestGKstats.head()
bestTotal = BestGKstats.sum(axis = 1, skipna = True)

# %%
YouthGKstats.head()
#youthTotal = YouthGKstats.sum(axis = 1, skipna = True) 
#youthTotal = YouthGKstats.sum(axis=0)
YouthGKstats.loc['Total',:]= YouthGKstats.sum(axis=0)

# %%
YouthGKstats
# Out:
#                        Name  AerialAbility  CommandOfArea  Communication  \
# 80119  Gianluigi Donnarumma           15.0           15.0           13.0
# Total  Gianluigi Donnarumma           15.0           15.0           13.0
#
#        Eccentricity  Handling  Kicking  OneOnOnes  Reflexes  RushingOut  \
# 80119           5.0      15.0     13.0       14.0      17.0        15.0
# Total           5.0      15.0     13.0       14.0      17.0        15.0
#
#        TendencyToPunch  Throwing
# 80119             14.0      11.0
# Total             14.0      11.0
